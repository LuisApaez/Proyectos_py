# %% [markdown]
# # 💥 Primeros pasos con ``Python`` 💥
#
# || <a style="background-color: #1bf8ff; color: #000000; border: none; padding: 10px 15px; border-radius: 5px;">Aplicando el proyecto</a> ||
# <a style="background-color: #1bf8ff; color: #000000; border: none; padding: 10px 15px; border-radius: 5px;">x</a> ||
# <a style="background-color: #1bf8ff; color: #000000; border: none; padding: 10px 15px; border-radius: 5px;">Cursos PyM</a> ||
# <a style="background-color: #1bf8ff; color: #000000; border: none; padding: 10px 15px; border-radius: 5px;">Luis Fernando Apáez Álvarez</a> ||
#
# ## 🪗 Proyecto 1 🪗
#
# ---

# %% [markdown]
# # 1. Realizamos la importación de nuestro módulo

# %%
from Base import tools as t

# %% [markdown]
# # 2. Creamos la base de datos y la tabla

# %%
# Obtenemos ayuda primero de la documentacion
print(help(t.definiciones))

# ejecutamos
t.definiciones()

# %% [markdown]
# # 3. Ejecutamos el proceso

# %%
print(help(t.proceso))

# ejecutemos la info de todo enero:
print("-----------------")

t.proceso('2025-01-01', '2025-01-31')
# Out:
# Help on function proceso in module Base:
#
# proceso(fecha_ini, fecha_fin=None)
#     Metodo en el cual simulamos la informacion de las ventas y adicionalmente realizamos
#     las inserciones. Se podra generar informacion de un solo dia o informacion de
#     todo un rango de fechas.
#
# None
# -----------------
# Estás insertando info de un rango fechas :D
# Comienzo del programa .....
# Generación exitosa al 2025-01-01
# Comienzo de las inserciones ....
# Inserción existosa
# Comienzo del programa .....
# Generación exitosa al 2025-01-02
# Comienzo de las inserciones ....
# Inserción existosa
# Comienzo del programa .....
# Generación exitosa al 2025-01-03
# Comienzo de las inserciones ....
# Inserción existosa
# Comienzo del programa .....
# Generación exitosa al 2025-01-04
# Comienzo de las inserciones ....
# Inserción existosa
# Comienzo del programa .....
# Generación exitosa al 2025-01-05
# Comienzo de las inserciones ....
# Inserción existosa
# Comienzo del programa .....
# ...

# %% [markdown]
# # 4. Comprobamos las inserciones

# %%
help(t.comprobar_fechas)
# Out:
# Help on function comprobar_fechas in module Base:
#
# comprobar_fechas()
#     Método para ver cuales fechas tenemos cargadas en la tabla
#     con base en una consulta SQL

# %%
t.comprobar_fechas()
# Out:
#          Fecha
# 0   2025-01-01
# 1   2025-01-02
# 2   2025-01-03
# 3   2025-01-04
# 4   2025-01-05
# 5   2025-01-06
# 6   2025-01-07
# 7   2025-01-08
# 8   2025-01-09
# 9   2025-01-10
# 10  2025-01-11
# 11  2025-01-12
# 12  2025-01-13
# 13  2025-01-14
# 14  2025-01-15
# 15  2025-01-16
# 16  2025-01-17
# 17  2025-01-18
# 18  2025-01-19
# 19  2025-01-20
# 20  2025-01-21
# 21  2025-01-22
# 22  2025-01-23
# 23  2025-01-24
# 24  2025-01-25
# 25  2025-01-26
# 26  2025-01-27
# 27  2025-01-28
# 28  2025-01-29
# 29  2025-01-30
# 30  2025-01-31
